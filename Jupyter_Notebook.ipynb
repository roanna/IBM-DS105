# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anna Roliak**
# </br>
# CS Graduate

# %% [markdown]
# *I am passionate about architecture and urban planning. I think that data science could be applied to develop modern cities and to change old ones for the better.*

# %% [markdown]
# ### Find area of a circle

# %%
PI = 3.14
radius = float(input ("Input circle radius here : "))
print ("The area of the circle is: " + str(PI * radius * 2))
# Out:
# Input circle radius here :  5
# The area of the circle is: 31.400000000000002

# %% [markdown]
# * Numbered list:
# 1. First
# 1. Second
# 1. Third
#
# ---
# * Tables:
# | header | header | header |
# |-|-|-|
# | cell | cell | cell |
# | cell | cell | cell |
# | cell | cell | cell |
# | cell | cell | cell |
#
# ---
#
# * Hyperlinks:
# 1. [Link to Google](https://www.google.com)
# 1. [Linkt to markdown cheatsheet](https://www.datacamp.com/tutorial/markdown-in-jupyter-notebook)
# 1. [IBM](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)
#
# ---
#
# * Images
# 1. ![Jaebum-Joo-459191521.jpg](attachment:127eec04-887b-47fd-943b-16611fc781ad.jpg)
# 1. ![cartoon-cute-doodle-lifestyle-cats-vector-1360941903.jpg](attachment:fb39fbc5-f8c8-4915-9b8d-59f618a00a64.jpg)
# 1. ![fish.png](attachment:68872be4-2dfd-4a43-b605-54a3b5962ba9.png)
# ---
#
# * Code
# ```Python
# PI = 3.14
# radius = float(input ("Input circle radius here : "))
# print ("The area of the circle is: " + str(PI * radius * 2))
# ```
#
# ---
# * Blocked quotes
#
#
# ---
# * Strikethrough
